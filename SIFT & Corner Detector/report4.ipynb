# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.environ['OPENCV_IO_MAX_IMAGE_PIXELS']=str(2**64)
import cv2

# %%
import os
os._exit(1)

# %%
import sys
import cv2 as cv
import numpy as np
from google.colab.patches import cv_imshow



img = cv.imread('drive/MyDrive/MachineVision/Re4/sejong.bmp')

gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)
dst_ = cv.normalize(dst, None, 255, 0, cv.NORM_MINMAX, cv.CV_8UC1)
img[dst>0.01*dst.max()]=[0,0,255]
cv_imshow(dst_)
cv_imshow(img)


img = cv.imread('drive/MyDrive/MachineVision/Re4/sejong.bmp')
corners = cv.goodFeaturesToTrack(gray, maxCorners=100,qualityLevel=0.1, minDistance=10)

for c in corners:
  x, y = c.ravel()
  cv.circle(img,(x,y),3,(0,0,255),-1)

cv_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA3E1F5E590>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA3E1F5E690>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA3E1F5E690>

# %%
img = cv.imread('drive/MyDrive/MachineVision/Re4/sejong.bmp')
rotateimg=cv.rotate(img,cv.ROTATE_90_CLOCKWISE)

gray = cv.cvtColor(rotateimg,cv.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)
dst_ = cv.normalize(dst, None, 255, 0, cv.NORM_MINMAX, cv.CV_8UC1)
rotateimg[dst>0.01*dst.max()]=[0,0,255]
cv_imshow(dst_)
cv_imshow(rotateimg)

img = cv.imread('drive/MyDrive/MachineVision/Re4/sejong.bmp')
rotateimg=cv.rotate(img,cv.ROTATE_90_CLOCKWISE)
corners = cv.goodFeaturesToTrack(gray, maxCorners=100,qualityLevel=0.1, minDistance=10)

for c in corners:
  x, y = c.ravel()
  cv.circle(rotateimg,(x,y),3,(0,0,255),-1)

cv_imshow(rotateimg)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA3E1F6A610>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA3E1F6A790>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA3E1FB9C90>

# %%
import sys
import cv2 as cv
import numpy as np
from google.colab.patches import cv_imshow



src  = cv.imread('/content/gdrive/MyDrive/MachineVision/Re2/DOG.jpg')
if src is None:
    print('Image load failed!')
    sys.exit()

dst = cv2.bilateralFilter(src, -1, 10, 5)

cv_imshow(src)



#gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#gray = np.float32(gray)
#dst = cv.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)
#dst_ = cv.normalize(dst, None, 255, 0, cv.NORM_MINMAX, cv.CV_8UC1)
#img[dst>0.01*dst.max()]=[0,0,255]
#cv_imshow(dst_)
# Out:
# Image load failed!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv_imshow

img = cv.imread('drive/MyDrive/MachineVision/Re4/sejong.bmp')
img = cv.resize(img,(1024,1024))


gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)
dst_ = cv.normalize(dst, None, 255, 0, cv.NORM_MINMAX, cv.CV_8UC1)
img[dst>0.01*dst.max()]=[0,0,255]
cv_imshow(dst_)
cv_imshow(img)


img = cv.imread('drive/MyDrive/MachineVision/Re4/sejong.bmp')
img = cv.resize(img,(1024,1024))
corners = cv.goodFeaturesToTrack(gray, maxCorners=100,qualityLevel=0.1, minDistance=10)

for c in corners:
  x, y = c.ravel()
  cv.circle(img,(x,y),3,(0,0,255),-1)

cv_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv_imshow
import subprocess
print (cv.__version__)
#subprocess.call("pip install -U opencv-python".split())
#!pip install opencv-contrib-python==4.4.0.44 
print (cv.__version__)
# Out:
# 4.4.0
# 4.4.0

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv_imshow
import subprocess

img = cv.imread('/content/drive/MyDrive/MachineVision/Re2/DOG.jpg')
rotateimg=cv.rotate(img,cv.ROTATE_90_CLOCKWISE)
rotategray= cv.cvtColor(rotateimg,cv.COLOR_BGR2GRAY)
cv_imshow(rotategray)
gray = cv.imread('/content/drive/MyDrive/MachineVision/Re2/DOG.jpg',cv.IMREAD_GRAYSCALE)
sift = cv.SIFT_create()
kp = sift.detect(gray,None)
kp2 = sift.detect(rotategray,None)
img=cv.drawKeypoints(gray,kp,img,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv_imshow(img)
rotateimg=cv.drawKeypoints(rotategray,kp2,rotateimg,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv_imshow(rotateimg)
# Out:
# <PIL.Image.Image image mode=L size=720x540 at 0x7FEE1DEFA210>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-b0a463dbc036> in <module>()
#       9 cv_imshow(rotategray)
#      10 gray = cv.imread('/content/drive/MyDrive/MachineVision/Re2/DOG.jpg',cv.IMREAD_GRAYSCALE)
# ---> 11 sift = cv.SIFT_create()
#      12 kp = sift.detect(gray,None)
#      13 kp2 = sift.detect(rotategray,None)
#
# AttributeError: module 'cv2.cv2' has no attribute 'SIFT_create'

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv_imshow
import subprocess

img = cv.imread('/content/drive/MyDrive/MachineVision/Re2/DOG.jpg')
img = cv.resize(img,(1080,1440))
cv_imshow(rotategray)
gray = cv.imread('/content/drive/MyDrive/MachineVision/Re2/DOG.jpg',cv.IMREAD_GRAYSCALE)
sift = cv.SIFT_create()
kp = sift.detect(gray,None)
img=cv.drawKeypoints(gray,kp,img,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv_imshow(img)
rotateimg=cv.drawKeypoints(rotategray,kp2,rotateimg,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# Out:
# <PIL.Image.Image image mode=L size=720x540 at 0x7FBB510B7E90>
# <PIL.Image.Image image mode=RGB size=540x720 at 0x7FBB510B7610>

# %%
img1 = cv.imread('drive/MyDrive/MachineVision/Re4/Mank2.png',cv.IMREAD_GRAYSCALE)
#img1 = cv.resize(img1,(480,640))
img2 = cv.imread('drive/MyDrive/MachineVision/Re4/books7.jpg',cv.IMREAD_GRAYSCALE)
#img2 = cv.resize(img2,(480,640))
sift = cv.SIFT_create()
kp = sift.detect(img1,None)
kp2 = sift.detect(img2,None)
img1=cv.drawKeypoints(img1,kp,img1,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv_imshow(img1)
img2=cv.drawKeypoints(img2,kp2,img2,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv_imshow(img2)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img1 = cv.imread('drive/MyDrive/MachineVision/Re4/Mank2.png',cv.IMREAD_GRAYSCALE)
img1 = cv.resize(img1,(480,640))
img2 = cv.imread('drive/MyDrive/MachineVision/Re4/books1.jpg',cv.IMREAD_GRAYSCALE)
img2 = cv.resize(img2,(480,640))
img3 = cv.imread('drive/MyDrive/MachineVision/Re4/books2.jpg',cv.IMREAD_GRAYSCALE)
img3 = cv.resize(img3,(480,640))
img4 = cv.imread('drive/MyDrive/MachineVision/Re4/books3.jpg',cv.IMREAD_GRAYSCALE)
img4 = cv.resize(img4,(480,640))
img5 = cv.imread('drive/MyDrive/MachineVision/Re4/books4.jpg',cv.IMREAD_GRAYSCALE)
img5 = cv.resize(img5,(480,640))
img6 = cv.imread('drive/MyDrive/MachineVision/Re4/books5.jpg',cv.IMREAD_GRAYSCALE)
img6 = cv.resize(img6,(480,640))
img7 = cv.imread('drive/MyDrive/MachineVision/Re4/books6.jpg',cv.IMREAD_GRAYSCALE)
img7 = cv.resize(img7,(480,640))
img8 = cv.imread('drive/MyDrive/MachineVision/Re4/books7.jpg',cv.IMREAD_GRAYSCALE)
img8 = cv.resize(img8,(480,640))
#cv_imshow(img1)
#cv_imshow(img2)
#cv_imshow(img3)
#cv_imshow(img4)
#cv_imshow(img5)
#cv_imshow(img6)


# find the keypoints and descriptors
sift = cv.SIFT_create()
#sift = cv.SIFT_create()  #xfeatures2d.SIFT_create()
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
kp3, des3 = sift.detectAndCompute(img3,None)
kp4, des4 = sift.detectAndCompute(img4,None)
kp5, des5 = sift.detectAndCompute(img5,None)
kp6, des6 = sift.detectAndCompute(img6,None)
kp7, des7 = sift.detectAndCompute(img7,None)
kp8, des8 = sift.detectAndCompute(img8,None)
bf = cv.BFMatcher()
matches = bf.match(des1,des2)
matches2 = bf.match(des1,des3)
matches3 = bf.match(des1,des4)
matches4 = bf.match(des1,des5)
matches5 = bf.match(des1,des6)
matches6 = bf.match(des1,des7)
matches7 = bf.match(des1,des8)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)
matches2 = sorted(matches2, key = lambda x:x.distance)
matches3 = sorted(matches3, key = lambda x:x.distance)
matches4 = sorted(matches4, key = lambda x:x.distance)
matches5 = sorted(matches5, key = lambda x:x.distance)
matches6 = sorted(matches6, key = lambda x:x.distance)
matches7 = sorted(matches7, key = lambda x:x.distance)
# Draw first 15 matches.
#img3 = cv.drawMatches(img1, kp1, img2, kp2, matches[:15], None,
#flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#img4 = cv.drawMatches(img1, kp1, img3, kp3, matches2[:15], None,
#flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
img5 = cv.drawMatches(img1, kp1, img4, kp4, matches3[:30], None,
flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#img6 = cv.drawMatches(img1, kp1, img5, kp5, matches4[:15], None,
#flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#img7 = cv.drawMatches(img1, kp1, img6, kp6, matches5[:30], None,
#flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#img8 = cv.drawMatches(img1, kp1, img7, kp7, matches6[:40], None,
#flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#img9 = cv.drawMatches(img1, kp1, img8, kp8, matches7[:40], None,
#flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
#cv_imshow(img3)
#cv_imshow(img4)
cv_imshow(img5)
#cv_imshow(img6)
#cv_imshow(img7)
#cv_imshow(img8)
# Out:
# <PIL.Image.Image image mode=RGB size=960x640 at 0x7FBB478835D0>

# %%
import matplotlib.pyplot as plt

plt.plot(np.arange(128), des1[matches[0].queryIdx])
plt.plot(np.arange(128), des5[matches[0].trainIdx]), plt.show()
plt.plot(np.arange(128), des1[matches[0].queryIdx])
plt.plot(np.arange(128), des5[matches[10].trainIdx]), plt.show()
# Out:
# ([<matplotlib.lines.Line2D at 0x7fbb473ce550>], None)

# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv_imshow



src  = cv.imread('/content/drive/MyDrive/MachineVision/Re2/DOG.jpg')
print (src)
#cv_imshow(src)
# Out:
# [[[202 223 238]
#   [201 222 237]
#   [201 222 237]
#   ...
#   [195 215 232]
#   [193 213 230]
#   [192 212 229]]
#
#  [[202 223 238]
#   [202 223 238]
#   [202 223 238]
#   ...
#   [194 214 231]
#   [193 213 230]
#   [192 212 229]]
#
#  [[202 223 238]
#   [202 223 238]
#   [202 223 238]
#   ...
#   [194 214 231]
#   [193 213 230]
#   [191 211 228]]
#
#  ...
#
#  [[157 161 209]
#   [139 144 189]
#   [145 151 194]
#   ...
#   [188 212 218]
#   [197 221 227]
#   [209 233 239]]
#
#  [[193 202 236]
#   [187 195 232]
#   [178 185 224]
#   ...
#   [195 217 223]
#   [208 230 236]
#   [214 236 241]]
#
#  [[201 212 240]
#   [198 208 238]
#   [168 176 213]
#   ...
#   [208 230 236]
#   [218 240 245]
#   [215 237 242]]]
